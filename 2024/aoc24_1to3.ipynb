# %% [markdown]
# https://adventofcode.com/2024/day/1
# ## --- Day 1: Historian Hysteria ---
# The Chief Historian is always present for the big Christmas sleigh launch, but nobody has seen him in months! Last anyone heard, he was visiting locations that are historically significant to the North Pole; a group of Senior Historians has asked you to accompany them as they check the places they think he was most likely to visit.
#
# As each location is checked, they will mark it on their list with a star. They figure the Chief Historian must be in one of the first fifty places they'll look, so in order to save Christmas, you need to help them get fifty stars on their list before Santa takes off on December 25th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day in the Advent calendar; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
#
# You haven't even left yet and the group of Elvish Senior Historians has already hit a problem: their list of locations to check is currently empty. Eventually, someone decides that the best place to check first would be the Chief Historian's office.
#
# Upon pouring into the office, everyone confirms that the Chief Historian is indeed nowhere to be found. Instead, the Elves discover an assortment of notes and lists of historically significant locations! This seems to be the planning the Chief Historian was doing before he left. Perhaps these notes can be used to determine which locations to search?
#
# Throughout the Chief's office, the historically significant locations are listed not by name but by a unique number called the location ID. To make sure they don't miss anything, The Historians split into two groups, each searching the office and trying to create their own complete list of location IDs.
#
# There's just one problem: by holding the two lists up side by side (your puzzle input), it quickly becomes clear that the lists aren't very similar. Maybe you can help The Historians reconcile their lists?
#
# For example:
#
# 3   4
# 4   3
# 2   5
# 1   3
# 3   9
# 3   3
# Maybe the lists are only off by a small amount! To find out, pair up the numbers and measure how far apart they are. Pair up the smallest number in the left list with the smallest number in the right list, then the second-smallest left number with the second-smallest right number, and so on.
#
# Within each pair, figure out how far apart the two numbers are; you'll need to add up all of those distances. For example, if you pair up a 3 from the left list with a 7 from the right list, the distance apart is 4; if you pair up a 9 with a 3, the distance apart is 6.
#
# In the example list above, the pairs and distances would be as follows:
#
# The smallest number in the left list is 1, and the smallest number in the right list is 3. The distance between them is 2.
# The second-smallest number in the left list is 2, and the second-smallest number in the right list is another 3. The distance between them is 1.
# The third-smallest number in both lists is 3, so the distance between them is 0.
# The next numbers to pair up are 3 and 4, a distance of 1.
# The fifth-smallest numbers in each list are 3 and 5, a distance of 2.
# Finally, the largest number in the left list is 4, while the largest number in the right list is 9; these are a distance 5 apart.
# To find the total distance between the left list and the right list, add up the distances between all of the pairs you found. In the example above, this is 2 + 1 + 0 + 1 + 2 + 5, a total distance of 11!
#
# Your actual left and right lists contain many location IDs. What is the total distance between your lists?

# %%
with open("i1.csv") as f:
    reports = f.readlines()
   
x, y = [], []
for i, line in enumerate(reports):
    xi,yi = line.strip().split("   ")
    x.append(xi)
    y.append(yi)
    print(xi,yi)
# Out:
# 16435 48069
# 29877 97906
# 75256 47355
# 25417 59861
# 32479 25840
# 93953 70621
# 21297 57288
# 41677 60361
# 42091 83949
# 74831 40059
# 53533 90866
# 83870 18758
# 78929 96272
# 85446 75644
# 31544 20514
# 44640 95346
# 34692 16581
# 58962 98590
# 96508 73793
# 51394 82185
# 67019 14797
# 21518 90866
# 62995 55469
# 92092 60333
# 10928 40778
# 34981 54922
# 26876 16871
# 66391 76794
# 30416 90866
# 91352 61520
# 24977 49695
# 49451 89237
# 21400 39529
# 87568 37175
# 96017 95346
# 90873 68295
# 91037 47664
# 75674 99513
# 11356 75031
# 66871 37296
# 33330 86365
# 66278 96190
# 18682 72272
# 42394 36663

# %%
d = 0
for xi,yi in zip(sorted(x), sorted(y)):
    d+=abs(int(xi)-int(yi)) 

d
# Out:
# 1722302

# %% [markdown]
# https://adventofcode.com/2024/day/1#part2
# --- Part Two ---
# Your analysis only confirmed what everyone feared: the two lists of location IDs are indeed very different.
#
# Or are they?
#
# The Historians can't agree on which group made the mistakes or how to read most of the Chief's handwriting, but in the commotion you notice an interesting detail: a lot of location IDs appear in both lists! Maybe the other numbers aren't location IDs at all but rather misinterpreted handwriting.
#
# This time, you'll need to figure out exactly how often each number from the left list appears in the right list. Calculate a total similarity score by adding up each number in the left list after multiplying it by the number of times that number appears in the right list.
#
# Here are the same example lists again:
#
# 3   4
# 4   3
# 2   5
# 1   3
# 3   9
# 3   3
# For these example lists, here is the process of finding the similarity score:
#
# The first number in the left list is 3. It appears in the right list three times, so the similarity score increases by 3 * 3 = 9.
# The second number in the left list is 4. It appears in the right list once, so the similarity score increases by 4 * 1 = 4.
# The third number in the left list is 2. It does not appear in the right list, so the similarity score does not increase (2 * 0 = 0).
# The fourth number, 1, also does not appear in the right list.
# The fifth number, 3, appears in the right list three times; the similarity score increases by 9.
# The last number, 3, appears in the right list three times; the similarity score again increases by 9.
# So, for these example lists, the similarity score at the end of this process is 31 (9 + 4 + 0 + 0 + 9 + 9).
#
# Once again consider your left and right lists. What is their similarity score?

# %%
def sim_score(left, right):
    score = 0
    for i in left:
        score += int(i) * right.count(i)
    return score

print(sim_score(x, y), sim_score(y, x))
# Out:
# 20373490 20373490

# %% [markdown]
# ## --- Day 2: Red-Nosed Reports ---
# Fortunately, the first location The Historians want to search isn't a long walk from the Chief Historian's office.
#
# While the Red-Nosed Reindeer nuclear fusion/fission plant appears to contain no sign of the Chief Historian, the engineers there run up to you as soon as they see you. Apparently, they still talk about the time Rudolph was saved through molecular synthesis from a single electron.
#
# They're quick to add that - since you're already here - they'd really appreciate your help analyzing some unusual data from the Red-Nosed reactor. You turn to check if The Historians are waiting for you, but they seem to have already divided into groups that are currently searching every corner of the facility. You offer to help with the unusual data.
#
# The unusual data (your puzzle input) consists of many reports, one report per line. Each report is a list of numbers called levels that are separated by spaces. For example:
#
# 7 6 4 2 1
# 1 2 7 8 9
# 9 7 6 2 1
# 1 3 2 4 5
# 8 6 4 4 1
# 1 3 6 7 9
# This example data contains six reports each containing five levels.
#
# The engineers are trying to figure out which reports are safe. The Red-Nosed reactor safety systems can only tolerate levels that are either gradually increasing or gradually decreasing. So, a report only counts as safe if both of the following are true:
#
# The levels are either all increasing or all decreasing.
# Any two adjacent levels differ by at least one and at most three.
# In the example above, the reports can be found safe or unsafe by checking those rules:
#
# 7 6 4 2 1: Safe because the levels are all decreasing by 1 or 2.
# 1 2 7 8 9: Unsafe because 2 7 is an increase of 5.
# 9 7 6 2 1: Unsafe because 6 2 is a decrease of 4.
# 1 3 2 4 5: Unsafe because 1 3 is increasing but 3 2 is decreasing.
# 8 6 4 4 1: Unsafe because 4 4 is neither an increase or a decrease.
# 1 3 6 7 9: Safe because the levels are all increasing by 1, 2, or 3.
# So, in this example, 2 reports are safe.
#
# Analyze the unusual data from the engineers. How many reports are safe?
#
# To begin, get your puzzle input.
#
# Answer:
#
#
# You can also [Share] this puzzle.

# %%
with open("i2.txt") as f:
    reports =  [[int(x) for x in line.strip().split(" ")] for line in f.readlines()]
    
reports[:10]
# Out:
# [[11, 12, 15, 18, 19, 18],
#  [84, 86, 88, 89, 92, 92],
#  [18, 19, 21, 23, 24, 25, 29],
#  [56, 59, 60, 61, 63, 66, 73],
#  [11, 13, 15, 13, 15],
#  [36, 38, 36, 39, 42, 43, 40],
#  [21, 22, 23, 21, 21],
#  [35, 37, 38, 39, 37, 41],
#  [56, 58, 55, 57, 58, 60, 61, 68],
#  [77, 78, 80, 80, 83, 85, 88, 89]]

# %%
safe = []
for report in reports:
    diffs = [report[i+1]-report[i] for i in range(len(report)-1)]
    if (all(1 <= diff <= 3  for diff in diffs) 
        or all(-3 <= diff <= -1  for diff in diffs)):
        safe.append(report)

print(len(safe))        
safe[:10]
# Out:
# 463
# [[93, 90, 87, 86, 84, 81, 80, 78],
#  [61, 64, 66, 69, 71, 74, 76],
#  [12, 9, 8, 7, 5],
#  [19, 17, 15, 12, 9, 6, 4, 3],
#  [69, 68, 65, 63, 62],
#  [86, 87, 90, 91, 92],
#  [72, 70, 69, 66, 63],
#  [89, 88, 86, 85, 84, 82, 79, 76],
#  [33, 35, 38, 39, 41],
#  [74, 73, 70, 68, 66]]

# %% [markdown]
# --- Part Two ---
# The engineers are surprised by the low number of safe reports until they realize they forgot to tell you about the Problem Dampener.
#
# The Problem Dampener is a reactor-mounted module that lets the reactor safety systems tolerate a single bad level in what would otherwise be a safe report. It's like the bad level never happened!
#
# Now, the same rules apply as before, except if removing a single level from an unsafe report would make it safe, the report instead counts as safe.
#
# More of the above example's reports are now safe:
# ```
# 7 6 4 2 1: Safe without removing any level.
# 1 2 7 8 9: Unsafe regardless of which level is removed.
# 9 7 6 2 1: Unsafe regardless of which level is removed.
# 1 3 2 4 5: Safe by removing the second level, 3.
# 8 6 4 4 1: Safe by removing the third level, 4.
# 1 3 6 7 9: Safe without removing any level.
# ```
#
# Thanks to the Problem Dampener, 4 reports are actually safe!
#
# Update your analysis by handling situations where the Problem Dampener can remove a single level from unsafe reports. How many reports are now safe?

# %%
def is_safe(report, problem_dampener=True):
    diffs = [report[i+1]-report[i] for i in range(len(report)-1)]
    if (all(1 <= diff <= 3  for diff in diffs) 
        or all(-3 <= diff <= -1  for diff in diffs)):
        return True
    if problem_dampener:
        for i,_ in enumerate(report):
            new_report = report.copy()
            new_report.pop(i)
            if is_safe(new_report, problem_dampener=False):
                return True
    return False
    
safe = []        
for report in reports:
    if is_safe(report, problem_dampener=True):
        safe.append(report) 
    
len(safe)
# Out:
# 514

# %% [markdown]
# https://adventofcode.com/2024/day/3
# ## Day 3
# --- Day 3: Mull It Over ---
# "Our computers are having issues, so I have no idea if we have any Chief Historians in stock! You're welcome to check the warehouse, though," says the mildly flustered shopkeeper at the North Pole Toboggan Rental Shop. The Historians head out to take a look.
#
# The shopkeeper turns to you. "Any chance you can see why our computers are having issues again?"
#
# The computer appears to be trying to run a program, but its memory (your puzzle input) is corrupted. All of the instructions have been jumbled up!
#
# It seems like the goal of the program is just to multiply some numbers. It does that with instructions like mul(X,Y), where X and Y are each 1-3 digit numbers. For instance, mul(44,46) multiplies 44 by 46 to get a result of 2024. Similarly, mul(123,4) would multiply 123 by 4.
#
# However, because the program's memory has been corrupted, there are also many invalid characters that should be ignored, even if they look like part of a mul instruction. Sequences like mul(4*, mul(6,9!, ?(12,34), or mul ( 2 , 4 ) do nothing.
#
# For example, consider the following section of corrupted memory:
#
# ``xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))``
# Only the four highlighted sections are real mul instructions. Adding up the result of each instruction produces 161 (2*4 + 5*5 + 11*8 + 8*5).
#
# Scan the corrupted memory for uncorrupted mul instructions. What do you get if you add up all of the results of the multiplications?

# %%
with open("i3.txt") as f:
    l = f.readlines()
    
with open("i3.txt") as f:
    instructions = "".join(f.readlines())
    
instructions
# Out:
# "$  mul(402,190))&<why(211,617)how()/;mul(506,313)[^^<!$#when(636,198),]mul(744,268)#&!what()&!;mul(631,641)where()@select()!@?(:;how()mul(25,288)&~^select()mul(683,657)'mul(505,315)+~:-mul(671,741)]{mul(397,54))?mul(511,935)where()select()where()-mul(525,623)mul(206,770){/}don't()from()mul(260,967)-how() -/[^(mul(500,994)!:mul(391,833)#)>who(),where(376,378)why();$mul(394,346)%:]^from()>:mul(130,944)who()>where()select()}:mul(952,439)?/how()from()^$why()do()@*{mul(557,916)&(who()mul(445,933):(,;>?mul(108,268)don't()select(574,441)-mul(132,870)from(){mul(441,660)why(),from();mul(919,820):#/%)why()*mul(194,790);#/^#select()?mul(981,514)$what(796,873)when() %from()mul(164,772):&:select()@mul(396,80)select()what()%),) mul(213,928){?who();@@mul(320,229)where(348,623)*when()when(180,565)mul(214,912)!mul(848,738)from()+):^how()-&[mul(378,433)select():%~mul(696,421)mul(364,341)?^don't()*&mul(89,441)how()select()what(),select()mul(423,822),?&(how()']what())$mul(21,844)&,select()/>^)'mul(469,230))when()where()*,#mul(569,594)why()what():{ select(200,250){())mul(661,628)#)why()from(325,19)who() mul(758,985){%&where()!how(213,616)*mul(394,768)mul(831,12)*where()>who(986,151)mul(962,504)$:<!)where()%$&when()mul(900,577)<>^[>;mul(948,363)$@;]mul(857,273) how() ,:!select(),[mul(31,766)} *mul(372,138)+,#!~(>;%mul(774,958)#}&+why()*when()mul(560,137)}mul(72,718)when()^{]':{how()/mul(985,120)@*[do()$how()mul(891,69)select()mul(546,834)@$mul(767,879)$$!/&why()?mul(876,495){^/&)who()<~]mul(911,71){?#mul(116
# ['mul(402,190)', 'mul(506,313)', 'mul(744,268)', 'mul(631,641)', 'mul(25,288)']

# %%
total = 0 
for match in matches:
    a,b = re.findall("\d{1,3}", match)
    total += int(a) * int(b)
    
total
# Out:
# 183788984

# %% [markdown]
# ##--- Part Two ---
# As you scan through the corrupted memory, you notice that some of the conditional statements are also still intact. If you handle some of the uncorrupted conditional statements in the program, you might be able to get an even more accurate result.
#
# There are two new instructions you'll need to handle:
#
# The ``do()`` instruction enables future mul instructions.
# The ``don't()`` instruction disables future mul instructions.
# Only the most recent do() or don't() instruction applies. At the beginning of the program, mul instructions are enabled.
#
# For example:
#
# ``xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)undo()?mul(8,5))``
# This corrupted memory is similar to the example from before, but this time the mul(5,5) and mul(11,8) instructions are disabled because there is a don't() instruction before them. The other mul instructions function normally, including the one at the end that gets re-enabled by a do() instruction.
#
# This time, the sum of the results is 48 (2*4 + 8*5).
#
# Handle the new instructions; what do you get if you add up all of the results of just the enabled multiplications?

# %%
instructions
# Out:
# "$  mul(402,190))&<why(211,617)how()/;mul(506,313)[^^<!$#when(636,198),]mul(744,268)#&!what()&!;mul(631,641)where()@select()!@?(:;how()mul(25,288)&~^select()mul(683,657)'mul(505,315)+~:-mul(671,741)]{mul(397,54))?mul(511,935)where()select()where()-mul(525,623)mul(206,770){/}don't()from()mul(260,967)-how() -/[^(mul(500,994)!:mul(391,833)#)>who(),where(376,378)why();$mul(394,346)%:]^from()>:mul(130,944)who()>where()select()}:mul(952,439)?/how()from()^$why()do()@*{mul(557,916)&(who()mul(445,933):(,;>?mul(108,268)don't()select(574,441)-mul(132,870)from(){mul(441,660)why(),from();mul(919,820):#/%)why()*mul(194,790);#/^#select()?mul(981,514)$what(796,873)when() %from()mul(164,772):&:select()@mul(396,80)select()what()%),) mul(213,928){?who();@@mul(320,229)where(348,623)*when()when(180,565)mul(214,912)!mul(848,738)from()+):^how()-&[mul(378,433)select():%~mul(696,421)mul(364,341)?^don't()*&mul(89,441)how()select()what(),select()mul(423,822),?&(how()']what())$mul(21,844)&,select()/>^)'mul(469,230))when()where()*,#mul(569,594)why()what():{ select(200,250){())mul(661,628)#)why()from(325,19)who() mul(758,985){%&where()!how(213,616)*mul(394,768)mul(831,12)*where()>who(986,151)mul(962,504)$:<!)where()%$&when()mul(900,577)<>^[>;mul(948,363)$@;]mul(857,273) how() ,:!select(),[mul(31,766)} *mul(372,138)+,#!~(>;%mul(774,958)#}&+why()*when()mul(560,137)}mul(72,718)when()^{]':{how()/mul(985,120)@*[do()$how()mul(891,69)select()mul(546,834)@$mul(767,879)$$!/&why()?mul(876,495){^/&)who()<~]mul(911,71){?#mul(116,462);:%<^'?}~why()mul(258,286)from()^#^?how()&who()mul(97,540)select()who()do(){^~~<why(955,532)@[ how()mul(682,75)~){?where()<mul(63,26)-where()^ <^mul(336,475)&when()mul(637,386)+*when()<^]mul(846,915)!mul(795,805)$what()[~#*@:/@mul(370,651)?$select()^how()}!mul(705,839)~*;%!^+why()do()!:)[#{mul(112,21)*mul(285,252)mul(451,396){&> )'mul(57,589)when()**mul(554,575)*+^mul(856,360)mul(530,200)@/&}*where()mul(588,2)who()$]mul(604,72)who()}from(524,212)mul(250,680)<;@;@how()?#mul(555,956)%(;:+<{(who()select()mul(377,822)+when()@[&{&from();*mul(457,538)mul(52,298)who()%when()%who()how()from(9,264)mul(452,941)where()+?,-don't()when()select()<mul(956,185)^}don't(){$/~how()][ #)mul(717,593,when(64,768):what()%(mul(922,407)#why(646,569)$(~:{#mul(3,438)+/#<*select())how()don't()!where();mul(853,725)%?}/!from()<?*mul!+>$''mul(229,512){{from()what()?!'^select()mul(185,787)<*mul(688,834)  @@what(),}select()>mul(825,27))~&!;mul(796,378)*+(-select(); mul!):{!;who()$how()why()don't()select()how(451,129)]#*^mul(852,354)[mul(596,889)mul(476,207):#what()-+mul(467,323) from()why()}(}^&:mul(955,498)]{;mul(797,177)mul(321,350):mul(784,667)mul(707,927)~%#why()why()what();mul(515,511)from(589,691)mul*&[mul(884,558)/mul(824,926))+from(331,316)where()!*!:mul(938,881)]mul(287,358what()@from(226,364)+:^)-when(361,935)select()mul(324,887)@where()select())(mul(430>&][mul(381,417)}*why()why()!*#~mul(729,14)>%what()'where(){}mul(483,820)when(206,921)&when()@how()mul(608,185)how(5,376)%mul(150,182)><when()@:@mul(953,86)mul(332,881)*mul(688,895)^<select()!%<+mul(5,990)>]/!( (+mul(78,588)what()@ why()when()*+from();;mul(837,417)who()mul(786,516)'how()%:~;%]who()<mul(576,960),@why()<<+'mul(160,572)*why()where()-when(353,689){[;mul(634,920)mul(482,207)( (when()<>:;-mul(917,130)\nwhy();[what()(,]mul(177,501)mul(346,27)when(428,856)who(){how()mul(513,432)what()']&where(),>?select(),do()+how()![where()mul(399,972)mul(862,828)when()?^&)mul(200,579)how()who()mul(79,535) <don't()<mul(450,265@/!mul(332,269)/select()why()-mul(436,976)&;$#-;^)what(878,202)mul(114,418}-~<! ,who()mul(394,75)<from()mul(51,262)from()#what()^*don't()%mul(133,6)mul(63,773)$%; ';@^what()!mul(142,703)where(178,667)}/(don't()how()mul(451,569)-~mul(395,265)+@>{select(684,626)){where()?)mul(52,852)&< @what()^what()]mul(807,491)&#@mul(130,14)<what()who():@mul(195,735)]when()<how()where()$,how()where()mul(310,933);[<$)mul(479,998),from()/where()@mul(583,819);select()}+$when()*mul(100,443)/$)mul(300,699)select()# #wha ...

# %%
mul_pattern = "mul\(\d{1,3},\d{1,3}\)"
do_pattern = "do\(\)"
dont_pattern = "don't\(\)"
mul = re.search(mul_pattern, instructions)
do = re.search(do_pattern, instructions)
dont = re.search(dont_pattern, instructions)
print(mul, do, dont, sep="\n")
# Out:
# <re.Match object; span=(3, 15), match='mul(402,190)'>
# <re.Match object; span=(458, 462), match='do()'>
# <re.Match object; span=(274, 281), match="don't()">

# %%
def set_do(inbetween, do):
    donts = re.split("don't\(\)", inbetween)
    dos = re.split("do\(\)", inbetween)
    last_dont = len(donts[-1])
    last_do = len(dos[-1])
    if last_dont < last_do and do:
        return False
    elif not do and last_do < last_dont:
        return True
    else:
        return do 
        
set_do(")&/;do()", False)
# Out:
# True

# %%
inbetweens = re.split(mul_pattern, instructions)
do = True
total = 0

for mul, inbetween in zip(matches, inbetweens):
    do = set_do(inbetween, do)
    a,b = re.findall("\d{1,3}", mul)
    print(do, mul, inbetween)
    if do:
        total += int(a) * int(b)
# Out:
# True mul(402,190) $
# True mul(506,313) )&<why(211,617)how()/;
# True mul(744,268) [^^<!$#when(636,198),]
# True mul(631,641) #&!what()&!;
# True mul(25,288) where()@select()!@?(:;how()
# True mul(683,657) &~^select()
# True mul(505,315) '
# True mul(671,741) +~:-
# True mul(397,54) ]{
# True mul(511,935) )?
# True mul(525,623) where()select()where()-
# True mul(206,770)
# False mul(260,967) {/}don't()from()
# False mul(500,994) -how() -/[^(
# False mul(391,833) !:
# False mul(394,346) #)>who(),where(376,378)why();$
# False mul(130,944) %:]^from()>:
# False mul(952,439) who()>where()select()}:
# True mul(557,916) ?/how()from()^$why()do()@*{
# True mul(445,933) &(who()
# True mul(108,268) :(,;>?
# False mul(132,870) don't()select(574,441)-
# False mul(441,660) from(){
# False mul(919,820) why(),from();
# False mul(194,790) :#/%)why()*
# False mul(981,514) ;#/^#select()?
# False mul(164,772) $what(796,873)when() %from()
# False mul(396,80) :&:select()@
# False mul(213,928) select()what()%),)
# False mul(320,229) {?who();@@
# False mul(214,912) where(348,623)*when()when(180,565)
# False mul(848,738) !
# False mul(378,433) from()+):^how()-&[
# False mul(696,421) select():%~
# False mul(364,341)
# False mul(89,441) ?^don't()*&
# False mul(423,822) how()select()what(),select()
# False mul(21,844) ,?&(how()']what())$
# False mul(469,230) &,select()/>^)'
# False mul(569,594) )when()where()*,#
# False mul(661,628) why()what():{ select(200,250){())
# False mul(758,985) #)why()from(325,19)who()
# False mul(394,768) {%&where()!how(213,616)*
# False mul(831,12)
# False mul(962,504) *where()>who(986,151)
# False mul(900,577) $:<!)where()%$&when()
# False mul(948,363) <>^[>;
# False mul(857,273) $@;]
# False mul(31,766)  how() ,:!select(),[
# False mul(372,138) } *
# False mul(774,958) +,#!~(>;%
# False mul(560,137) #}&+why()*when()
# False mul(72,718) }
# False mul(985,120) when()^{]':{how()/
# True mul(891,69) @*[do()$how()
# True mul(546,834) select()
# True mul(767,879) @$
# True mul(876,495) $$!/&why()?
# True mul(911,71) {^/&)who()<~]
# True mul(116,462) {?#
# True mul(258,286) ;:%<^'?}~why()
# True mul(97,540) from()^#^?how()&who()
# True mul(682,75) select()who()do(){^~~<why(955,532)@[ how()
# True mul(63,26) ~){?where()<
# True mul(336,475) -where()^ <^
# True mul(637,386) &when()
# True mul(846,915) +*when()<^]
# True mul(795,805) !
# True mul(370,651) $what()[~#*@:/@
# True mul(705,839) ?$select()^how()}!
# True mul(112,21) ~*;%!^+why()do()!:)[#{
# True mul(285,252) *
# True mul(451,396)
# True mul(57,589) {&> )'
# True mul(554,575) when()**
# True mul(856,360) *+^
# True mul(530,200)
# True mul(588,2) @/&}*where()
# True mul(604,72) who()$]
# True mul(250,680) who()}from(524,212)
# True mul(555,956) <;@;@how()?#
# True mul(377,822) %(;:+<{(who()select()
# True mul(457,538) +when()@[&{&from();*
# True mul(52,298)
# True mul(452,941) who()%when()%who()how()from(9,264)
# False mul(956,185) where()+?,-don't()when()select()<
# False mul(922,407) ^}don't(){$/~how()][ #)mul(717,593,when(64,768):what()%(
# False mul(3,438) #why(646,569)$(~:{#
# False mul(853,725) +/#<*select())how()don't()!where();
# False mul(229,512) %?}/!from()<?*mul!+>$''
# False mul(185,787) {{from()what()?!'^select()
# False mul(688,834) <*
# False mul(825,27)   @@what(),}select()>
# False mul(796,378) )~&!;
# False mul(852,354) *+(-select(); mul!):{!;who()$how()why()don't()select()how(451,129)]#*^
# False mul(596,889) [
# False mul(476,207)
# False mul(467,323) :#what()-+
# False mul(955,498)  from()why()}(}^&:
# False mul(797,177) ]{;
# False mul(321,350)
# False mul(784,667) :
# False mul(707,927)
# False mul(515,511) ~%#why()why()what();
# False mul(884,558) from(589,691)mul*&[
# False mul(824,926) /
# False mul(938,881) )+from(331,316)where()!*!:
# False mul(324,887) ]mul(287,358what()@from(226,364)+:^)-when(361,935)select()
# False mul(381,417) @where()select())(mul(430>&][
# False mul(729,14) }*why()why()!*#~
# False mul(483,820) >%what()'where(){}
# False mul(608,185) when(206,921)&when()@how()
# False mul(150,182) how(5,376)%
# False mul(953,86) ><when()@:@
# False mul(332,881)
# False mul(688,895) *
# False mul(5,990) ^<select()!%<+
# False mul(78,588) >]/!( (+
# False mul(837,417) what()@ why()when()*+from();;
# False mul(786,516) who()
# False mul(576,960) 'how()%:~;%]who()<
# False mul(160,572) ,@why()<<+'
# False mul(634,920) *why()where()-when(353,689){[;
# False mul(482,207)
# False mul(917,130) ( (when()<>:;-
# False mul(177,501)
# why();[what()(,]
# False mul(346,27)
# False mul(513,432) when(428,856)who(){how()
# True mul(399,972) what()']&where(),>?select(),do()+how()![where()
# True mul(862,828)
# True mul(200,579) when()?^&)
# True mul(79,535) how()who()
# False mul(332,269)  <don't()<mul(450,265@/!
# False mul(436,976) /select()why()-
# False mul(394,75) &;$#-;^)what(878,202)mul(114,418}-~<! ,who()
# False mul(51,262) <from()
# False mul(133,6) from()#what()^*don't()%
# False mul(63,773)
# False mul(142,703) $%; ';@^what()!
# False mul(451,569) where(178,667)}/(don't()how()
# False mul(395,265) -~
# False mul(52,852) +@>{select(684,626)){where()?)
# False mul(807,491) &< @what()^what()]
# False mul(130,14) &#@
# False mul(195,735) <what()who():@
# False mul(310,933) ]when()<how()where()$,how()where()
# False mul(479,998) ;[<$)
# False mul(583,819) ,from()/where()@
# False mul(100,443) ;select()}+$when()*
# False mul(300,699) /$)
# False mul(824,627) select()# #what()?:(^
# False mul(884,328) #>
# False mul(434,697) when()%who(255,459)
# False mul(522,208) ?how(),,*)#
# False mul(296,945)  !&/
# False mul(637,905) -~!what()when(),,%mul(127[
# False mul(375,117) ~from()/where()/where()
# False mul(873,410) (<;select()how():!^{mul(856from()][from()}&when(331,921)
# False mul(460,138) '@/mul(777,739>when()!^!)
# False mul(820,107) !'{why()<~/<
# False mul(887,760) /<(*;&
# False mul(701,198) /
# False mul(108,795) +@@,{ where():
# False mul(491,644) why()]#&don't()#+where()
# False mul(148,474)
# False mul(216,458) !
# False mul(808,178) <,when()[(#mul(205^from()]@(where()?@
# False mul(807,17) !@from();~%:]})
# False mul(97,8) >when()when()+:(what()@)
# False mul(324,169)
# False mul(396,755) select()
# False mul(856,118) !#select()^&#];when()don't()$where()/^{~{how()
# False mul(683,431) $*who()who()#when()
# False mul(946,398) /
# False mul(902,742)
# False mul(448,592) (
# False mul(750,527) '
# False mul(104,754) ]/mul(98,232*,select()(!~/<{
# False mul(959,509) ^
# True mul(564,313)  '$~@/do()when(642,16);what() <#(+!
# False mul(283,666) $]'mul(945from()*]!who()[%who()'*#don't()<![select()where(387,153)
# False mul(323,423)
# False mul(897,782) what()}where(552,799)@#what()
# False mul(965,10) &why();where()[$#!select(){
# False mul(515,710) ?$
# False mul(442,335) why(),!?*:
# False mul(410,907) &<who(526,485)who()!)when():%>
# False mul(21,969) @what()select()select()?
# False mul(942,472)
# True mul(36,303) ' what() ?select()why()^do() /$-who()::
# True mul(783,530) ~
# True mul(74,743) '$what()$:%?
# True mul(681,793) ;~^;>do()who()who()>}mul(391@^
# True mul(171,461) where()%!-,
# False mul(707,127) ![<<&don't()+
# False mul(641,578) ^?
# False mul(431,871) where()how()what()what(89,960)}(]
# False mul(610,323) mul,+
# False mul(343,108) <why()what()
# False mul(902,793) '
# False mul(535,881) [where(661,90)#who())?#![}
# False mul(782,524)
# False mul(662,436) select()>why()why()
# False mul(186,254) '&[^mul(397%from()>*why()%-
# False mul(518,739) ?*]!who()!select(839,279)<
# False mul(394,539) }from()don't()(where()how()} who()~
# False mul(32,988) ^why()where()+?from()(
# False mul(459,826) ]
# False mul(95,871) };
# False mul(626,919) ?&{select()&/;
# False mul(161,733)  '++{;from()
# False mul(662,339) ,#%
# False mul(246,943) * +
# False mul(555,251) where()#what()what(){+,;,who()
# False mul(374,548) what()what()%(
# False mul(84,228) >]+select()
# False mul(536,784) [
# False mul(917,825) where()+*how()mul(893,249;what()(
# False mul(891,755) mul&
# False mul(511,464) )${,#@@
# False mul(730,485) what()where()'when()mul:who()
# False mul(592,512) ][,
# False mul(111,611) [why(52,524),*]@select()(mul(829})' *~- [)
# False mul(925,978) how(838,283)+#{>when()?who(764,939)from()
# False mul(538,803) [*#who(182,485)how()select()
# False mul(671,684) >&where()how()$what() }{
# False mul(453,150) /why(106,337)+<#(
# False mul(197,568) ++[--from(475,981)where()&{
# False mul(466,89)  &;/mulwhy()~(@*who()/!#
# False mul(30,648) 'why(594,849)(select()(
# False mul(829,947) what()from()(select()
# False mul(903,174)
# False mul(462,421) ,-,@select()from()select()
# False mul(631,703) &when()!when()^%;),
# False mul(917,971)
# False mul(473,892)
# False mul(800,49)  don't(){/~>,why()[*
# False mul(571,734) when()why()>%)*who())]
# False mul(283,803) <(
# False mul(752,111) ~
# False mul(393,613) why(); %<,(where()'&
# False mul(257,15)
# False mul(14,159) &
# False mul(502,324) ]
# False mul(542,760) what()how()when(294,303)-%:when()
# False mul(726,492) >}why(),how()
# False mul(169,827)
# False mul(564,652) ^: ^~[ mul(859how()#how()))%@
# False mul(403,8)
# False mul(507,846) ~
# False mul(470,989)
# !!{[){
# False mul(498,119) #mul(58,989+who()?*{! [
# False mul(206,173) %~{
# False mul(154,721) who()from()how()}%^*;how()@
# False mul(451,125) {~
# False mul(386,969) <-
# False mul(890,369) !<:
# False mul(657,994) !*{+]-,where()when()when()
# False mul(898,340) ]why():
# False mul(352,838)  how()(#who()<
# False mul(21,663) [%)who()?how():&when(173,843)
# False mul(502,23) how()&]^}-^>where()
# False mul(807,634)  mul(681,55$( ,
# False mul(176,10) &${what()~what()
# False mul(564,162) '(what()why()@~]
# False mul(526,996) !%select()
# False mul(993,991) !-
# False mul(118,854) /'!?
# False mul(74,965) ?~-?
# False mul(913,115) who())-({when()select()]
# False mul(990,573) /[who()where()when()<%!mul, ]~#/
# False mul(226,132) &from()^}%$
# False mul(431,657)
# False mul(21,346) [who())where(690,880)',- ,
# False mul(174,190) what()how(298,600)-
# False mul(755,197)
# False mul(560,222) who(){>&$what()from(853,522)
# False mul(67,261) what()$when()[mul(933)from(881,714)[when()#~(]{
# False mul(775,385) !
# False mul(381,343) don't()[who()how() where()/
# True mul(460,761) do()<}$%;<>how()'
# True mul(83,660) (
# False mul(274,997) [where()mul(539,808'&select()*don't()(
# False mul(274,981)
# False mul(414,738) }/#who()[]
# True mul(638,411) {$do()&<?:what()&why()%who()
# False mul(672,195) &[?don't()when()+ ?>
# False mul(772,21) '}<<
# False mul(90,631) >@[&;select()
# False mul(869,108)  $*
# False mul(827,339) ^$+:([&#!mul(801when()~}
# False mul(586,599) who(851,624)%&why()'when()'
# False mul(139,133) +:'/>when()[!
# False mul(565,566) *'!$){#~?
# False mul(618,83)
# False mul(765,263) +
# False mul(344,377) why()/+how()#'{how(521,404) !
# False mul(302,909) /select(536,767)@why()-why()'where()why(468,917)
# False mul(632,525) {:
# False mul(383,809) from()>who()(@who()
# True mul(597,59) <>select();when();select()who()?<do()$*
# True mul(79,440) when()/(}
# True mul(565,850) $
# True mul(368,953) {[how()where()
# True mul(767,182) :*}from();!,-
# True mul(410,122) what()from()$why()when()%/&
# True mul(246,726) %!-
# True mul(343,179) $when()%
# True mul(816,33)  {-?why()
# True mul(858,204) ,:;%#;$mul(340,519(
# True mul(739,205) select()@!:
# True mul(891,670) why();*]/'select()
# True mul(790,933) ]why(5,493)how()[?when(519,92)when()
# True mul(142,6) /**>'>where()select()
# True mul(963,13) *:(>'
# False mul(18,872) ,don't() how()when()/'*
# False mul(465,102) '
# False mul(133,919) (#+mul(590,510! from()
# False mul(820,448) }[,from()from() (
# False mul(442,548) [
# False mul(977,871)
# False mul(606,74) }who()+select()who()
# False mul(129,889) ^:)mul>!
# False mul(310,726) /+
# False mul(49,487) who()from()*what()
# False mul(615,825) /)where()]:
# False mul(266,421) }}don't()
# False mul(56,163) }don't()(how();select(908,869)+how()where()
# False mul(288,896)
# False mul(391,531) mul(872^
# False mul(152,112) $
# False mul(889,862) '^,from()
# False mul(562,569)
# False mul(236,30) ^ *{';when()!(
# False mul(634,71) >]-why()]what(83,46)when()/>how()
# False mul(438,21) ?,?{^?
# False mul(993,470) what()
# False mul(190,720) {<[when()where()from()
# False mul(123,502) /%where()@mul(339,904why()where()
# False mul(178,842) ;) /
# False mul(737,234) how()
# False mul(985,241)  !
# False mul(349,197) **?~-
# False mul(22,535) <[
# False mul(460,416) &(&why()
# True mul(181,581) when()&do()[how()when(), mul(250,415how()@-%*:who()*
# True mul(353,992) :@
# True mul(247,102) *when()what()
# False mul(624,872) where()?why(607,695)#don't()?when()from()%@<
# False mul(589,215) +select()-^
# False mul(626,138)
# False mul(726,746)
# False mul(738,410) >)from()where()
# False mul(545,174) !where(808,172),;:*'mul/^(#
# False mul(12,180) ^:when()-$^'mul(670,694(why(117,443):
# False mul(314,309) ;'@what()
# False mul(790,161)
# False mul(147,178) &what()where(620,466)&who()[-]*where()
# False mul(441,381) why()^][}'~$
# False mul(138,111) {
# False mul(795,46) <+) <
# False mul(207,817)
# False mul(360,197) why()
# False mul(908,513) ?,,where()!$select()
# False mul(976,931) 'when()*&,~{:don't()
# False mul(842,241) }$]/select()@>what()[
# False mul(329,926) :(from()how()$:
# False mul(161,472) don't()-@$-from(245,221)]+
# False mul(178,909) :/how()
# False mul(729,950)
# False mul(310,170) >]
# False mul(868,180)
# False mul(685,89) }
# False mul(464,132) }what(690,794)!who()!mul(670,698']>~
# False mul(54,26) -when(827,257)?)when()#/?when()#!/usr/bin/perlfrom()--{where())what()(
# False mul(601,827)
# @)+
# False mul(943,407) from()how()]'how()[where()how()]]
# False mul(516,728) what()/why()}}
# False mul(651,195) <-+ why() ?'
# False mul(159,449) who(472,480)select()^{}/]
# False mul(889,383) #{select()]>why(457,182)
# False mul(717,768)
# False mul(582,481) ~>{select()from()~@{>'mul(25,532#}who())
# False mul(232,573) where()>$?) !
# False mul(27,868)
# True mul(24,375) ^~from()#where()do()how()>
# True mul(34,942) '!;,,
# True mul(511,814) ?-
# True mul(369,392) <:{{how()}{what()
# True mul(643,828)
# True mul(12,913)
# True mul(384,257) from()~select(){ +$$
# True mul(607,455) {who()!{$ )#/!
# True mul(747,552) how()*(( /-+::
# True mul(333,364)
# True mul(257,957) how()*?select(914,438)% ~,
# True mul(85,930) do()where(){+#
# True mul(538,737) when()^'<~^/
# True mul(959,252) ?,%what()*-^ where()
# True mul(435,422)
# True mul(634,612) #where()mulwhere()
# True mul(842,759) ,}{select(863,784){[do()who()}*+
# True mul(631,814) ,#what());[}why(616,35)%
# True mul(768,481) ;where()/)
# True mul(432,507) >{!)>who()who()select()how()
# True mul(60,211) &)!>{%>(mul:$?(?~@ }
# True mul(960,9) what()what()*what()when()+];
# True mul(252,399) - ~'mul(678]+&!
# True mul(510,368) what()?:?} !@>[
# True mul(674,905)
# True mul(763,579) how()/why()^
# True mul(771,675)
# True mul(565,944)
# False mul(708,226) 'who(345,580)#<where(248,141)from()don't()when()who()#from()>~<
# False mul(669,13) $select(856,127),[
# False mul(228,509)
# False mul(665,556) } why()
# False mul(820,340) <]$:])@^<when()
# False mul(430,345)
# False mul(349,192) from()who()<why()#>!who()
# False mul(623,920) [mul(673@#+/
# False mul(906,455) &^where()}#who()mul(331from()$'+from()
# False mul(969,326) select()
# False mul(342,396) where()[$(how()[/;/-
# False mul(319,806) >how()[*
# False mul(374,571) ~#
# False mul(767,564) who()
# False mul(724,513) %:-[-;@)
# False mul(559,103) %{[$~
# False mul(495,144)
# False mul(966,554) who()<<why()who();)~
# False mul(485,851) +[]select()>
# False mul(935,69) (
# False mul(745,465) from()
# False mul(788,539) select();/^
# False mul(385,82) }:/+from()select()^/~
# False mul(939,676)
# False mul(481,330) #!%how(){who()?
# False mul(542,441) +[
# False mul(385,342) %when()!^?select()when()select()$-
# False mul(394,223) ?who()how(),who()
# False mul(197,885) @<$@-%%&:#
# False mul(753,360) {select()when()+)when():select()[
# False mul(979,895) why()(>;!(mul(91,833*$#
# False mul(372,24) where()@>
# False mul(189,679) %*
# False mul(97,308)
# False mul(657,601) who()>
# False mul(906,401) ->*; #&)-
# False mul(808,51)  from()(what()
# False mul(723,974) [<{when()
# False mul(947,448) !'@)$^who():
# False mul(440,545)
# False mul(172,802) '<?
# False mul(716,119) where()
# True mul(319,32) ;when())do()])where()(#where()>who()]
# True mul(728,960) <#select(232,786)select(91,643)what()where()
# True mul(525,770) {do())^ })
# True mul(695,142) )who(),;why() #&{why()
# True mul(558,127) @]+ )[$&*
# True mul(126,171) how()why(),<,&how()^>!
# False mul(331,359) :)}]&don't()^'how()+*^where()where()@
# True mul(715,122)  */do()what()):why();where()>
# False mul(242,204) when()(when()from();,)}^$don't()/where()/^
# False mul(353,405) how()mul(910when()what()[,]/&don't()-!how()who()who();from()}where()
# False mul(562,824) where()from()what()who()
# False mul(333,11)
# False mul(842,629)
# False mul(778,805) #}+$^
# False mul(806,747) >
# False mul(741,908) when()!^
# False mul(110,482) why()where()
# False mul(579,772) >&$?
# False mul(636,907) @}select()-
# False mul(526,945) (
# False mul(166,764) -(from()(*what()how():
# False mul(476,49) ?'?#mul(246how()#{
# False mul(477,38) *:who()who():,what()-+
# False mul(544,656) &?{;>/
# False mul(514,32) ,select()*what();what(394,396)[ ?&
# False mul(964,815) {^select()@select():#]%
# False mul(562,410)
# False mul(944,789) ;when();*
# False mul(750,209) ~/^$~$-
# False mul(487,591) * ;;how()
# False mul(230,18) ;?<
# False mul(380,386)
# False mul(949,615) ,-{,@select()^
# False mul(557,379) !how(900,63)what()+
# False mul(423,189) ]@when()] :*(:~
# False mul(844,661) where();:when()}{[ [*
# False mul(631,480)
# False mul(484,570) $
# False mul(286,807) mul(761,125~#)*@~
# False mul(715,248)
# False mul(513,214) &<*,'{)
# False mul(420,876) -what(531,549)*@$where()$#)
# False mul(177,619) *what()!
# False mul(819,380) select()<
# False mul(263,636) ?how(): <:';
# False mul(763,577)
# [}[%*:
# False mul(416,291) }<<[],@
# False mul(80,21) }<{how()[who()):@
# False mul(147,560)
# False mul(9,445) who()@',what()
# False mul(797,562) ]!
# False mul(128,286) %[$-who()
# False mul(331,938) from(){;:
# False mul(159,223) *why()'-[what()
# False mul(684,152) -*where()<who(619,345)-,
# False mul(433,596) who()
# False mul(793,372) {
# False mul(935,16) <from(54,483)[select()[where(629,864)
# False mul(204,768)
# False mul(864,108) !
# False mul(147,548) from()don't() }$
# False mul(827,996) ^
# False mul(420,422)
# False mul(61,127) how()what()
# False mul(245,365) @&<'^+^>
# False mul(651,974) [[!@),{@
# False mul(333,723) } /<
# False mul(198,582) +
# False mul(631,8)
# False mul(21,630) what(),what()]!who()how()what()<
# False mul(358,326) where()&]~:[
# False mul(372,505) from()+from()
# True mul(351,931) -:do()#?what()where()
# True mul(571,244) >]%why()&mul(809,5~*/&&why()>
# True mul(518,122) where()#why()}what()
# True mul(579,300) +
# False mul(361,809) '/select(898,768)>%][$(don't(){[
# False mul(294,704) >[>&];why()why();
# False mul(331,74)
# False mul(694,47) }
# False mul(399,272) ]/-
# False mul(104,924) when()
# False mul(642,304) when()what(347,469)>from()~^
# False mul(429,733) when()<what(){>?why()?
# False mul(125,283) select()#&(}&
# False mul(136,666) select()][who():[
# False mul(570,389) ? when()where()%what()>/how()
# False mul(713,887) :]~who()+@!}
# False mul(98,67) ?{}select()'
# True mul(536,7) &when()do()when()>
# True mul(884,110) *when()) !'
# True mul(201,681) @#')
# True mul(593,332) from()^,do()'why()#]<why()'(;+
# True mul(180,819) ]
# True mul(902,212) /@
# True mul(90,446) -
# False mul(893,69) ~];select()why(100,859)!don't()-'
# False mul(86,991) ,}][from()don't()+(~why())
# False mul(590,379)
# False mul(405,424) how()
# False mul(420,456) ?:#>from()! don't()when()how()
# False mul(916,632) %?,'mul(385?select()
# False mul(908,719) ]mul)
# False mul(539,350) $*@ <when() <$where()
# False mul(405,412) (+why()# +select()select()
# False mul(143,163) '!>({/{^<when(442,660)
# False mul(140,644)  who()why()
# False mul(250,287)
# False mul(822,187) )mul#'-when()select()how()+/$
# False mul(888,819)
# False mul(212,723) !<select(908,31)[$/
# False mul(372,211) who()&]
# False mul(854,457)
# False mul(198,967) &;where()??}-+/
# False mul(669,611) from()
# False mul(62,603) :what(364,527)*);[select()^)/
# False mul(215,373) -+@
# False mul(765,970) )
# False mul(218,4)
# False mul(482,465) ^]
# False mul(677,699) how()$^,];from()'
# False mul(856,173) #
# False mul(816,115) #
# False mul(647,891) !
# False mul(726,735) from();<[!select()-how()
# False mul(298,848) who(),#who()how()mul(44,988@++!~
# False mul(2,969) : /]where()^where()why()who()
# False mul(595,699) mulwhen(779,246)where(){when()how()>how()<
# False mul(270,688) when(){why()from()
# False mul(324,127) ^select()*!~'<}-
# False mul(354,982) (select()-
# False mul(980,215) ]+from()&#>?!
# False mul(614,656) >what()where()@?why()-?
# False mul(220,163)
# False mul(355,585) ?why()how()
# False mul(419,411) %;
# False mul(184,742)
# False mul(626,880) $what()>;don't()],'$(select()mul(736}when(),
# False mul(676,2) who()*<how();*]%(
# False mul(765,856) )+%who() how()-%+<mul(366?((how()>,;
# False mul(553,221) <<>why()
# False mul(813,625) ^!>$who();
# True mul(496,557) >]*  how()do()]<;$<@where()select(774,55);!
# True mul(222,55) #<>,!>)what()
# True mul(136,746) from()who()]',what()/;where()where()
# False mul(970,908) >(don't()]
# False mul(237,672) select()^@)'%
# False mul(498,420) :+<@<%%-}
# False mul(937,73) who(839,971)&select()
# True mul(996,665) $&&from()do()
# True mul(143,849) &where()where()%,#
# True mul(134,708) ?from(913,546)*{?([&
# True mul(205,222) why()[,'how(166,502)select()#&mul[-
# True mul(616,898) }select()]}( why()@(+mul(898,124?*how()@select()
# True mul(155,570) where(705,139)]@
# True mul(89,802) who() -$,{&
# True mul(676,57) !+who()$do()&~]%>?{ >
# True mul(91,478) < <from()!((*&
# True mul(105,40) ]
# True mul(346,548) when()]'how(669,25)
# True mul(738,600) ]]]'when()>
# True mul(918,629) :
# True mul(161,824) ['when()~where()from()!;:>
# True mul(600,436) what())from()
# True mul(996,979) ~{]what()select()!+&%/
# True mul(206,328) }}who()] $+$
# True mul(130,592) $^)@@/,when()}%
# True mul(50,834) when()select()%
# True mul(73,823) ';*@when()
# True mul(865,121)
# True mul(71,583)
# ,^:
# True mul(316,791)
# True mul(495,908) from()when(){&->why()
# True mul(398,188) @}*where(),how()%mul(645,82how(830,734)who()[
# True mul(221,419) (%where()&do(){)from()from()who()
# True mul(693,760) <:]$^'^)from()mul)
# True mul(516,571) #how()>^why()why()[,'why(370,828)
# True mul(325,165) where(425,351)<,>)mul(661,792{))$~-what())who()#[
# True mul(346,3) [$where()%^*]who()+/
# True mul(248,163) do()-@when() when()>+#*mul(698~
# True mul(57,514) /~]#{from()*
# True mul(871,508)
# True mul(498,284) [
# True mul(840,612) from()who()select()when(277,99)*select()*
# True mul(897,30) %
# True mul(405,945) #</}^(do()<+select()@where()$when();#-
# True mul(346,138) #why(433,827)>/
# True mul(354,691) select()how()?)
# False mul(224,179) ?]what()don't();?;when(244,299)who();when()>
# False mul(50,319) %]
# False mul(34,718) :
# False mul(943,652) when()^:+where()from()'from()}
# False mul(507,740) +/why()*why()#%don't() when()#'>+*>mul(231,697%how(175,144)
# False mul(755,156) +~where() :from()
# False mul(927,385) /%$)*+(who(212,81)>
# True mul(80,489) #()do()
# True mul(651,799) :*,select()%&%where() mul(911,455who()}
# True mul(202,247) ~-why()+*
# True mul(854,23) ;+%^:<
# True mul(961,171) {@#
# True mul(128,126) where()!-
# True mul(473,221) %%~#what()@
# True mul(153,592) $do(){ !,&from(188,13)&!:where()
# True mul(639,252) %select(112,432)where()
# True mul(504,573) %]}$do()
# True mul(150,892) how()
# True mul(602,833) ?who()+-why()%[}where()
# True mul(53,697) )-
# True mul(270,818) %where(); /<where()$<
# True mul(185,555) ?how()}
# True mul(940,746) />
# True mul(701,602) ,#from()when()mulwho()
# True mul(183,908)
# True mul(12,827) how()
# True mul(332,704) ][})how(){~when()$
# True mul(936,771) ^)when()when()
# True mul(953,541) #where()/who()who();from()$# do()%where(){^
# True mul(207,683)
# True mul(336,694) ,how()~%
# True mul(783,475) why()>@<do()
# True mul(500,657) ~@
# True mul(924,686) > *!?[from()@
# True mul(493,198) *)%! / )why()[
# True mul(355,72) when()>;<$how()$(]>do()(?~(!&^select()%
# True mul(936,935) }how()~why()why()what()~'
# True mul(17,105) &{what(803,472)from()]<who()@who()
# True mul(869,268) where()^select()^&[<
# True mul(135,402) what(){
# True mul(732,550)  {where()
# False mul(240,194) where()don't()@~
# False mul(412,850) why()~#how()
# True mul(149,595) !$>@ ,do()@why()*why()[
# True mul(867,291) }]
# True mul(330,855) ~&)'%<
# True mul(712,568) (<how()%
# True mul(913,542) (why()@when()where()~
# True mul(370,272) $/
# True mul(646,518) ]from()>@where()>from(455,831)%
# True mul(522,755) %
# True mul(555,59) ];'who()from()select();what()'%
# True mul(729,27) (how()'?[!@do():@{
# True mul(949,316) when()]'*,/,why()where()
# True mul(931,532) how()^who(84,611)[?:#
# True mul(383,846) <% [where()select()@%%
# True mul(325,437) $why()~{/+(@
# True mul(601,128) who()>],select()#;when()%
# True mul(783,128) <!
# True mul(928,854) who()#select(532,884)how()]
# True mul(743,757) <^where()/:what()(where(831,396)select()?
# True mul(723,274) $}!{)%
# True mul(125,779) ,!^{'(
# True mul(104,510) +
# True mul(878,917)
# True mul(838,207) ( where(389,343)%-)]
# True mul(967,47) (^#$/</&
# True mul(590,941) from()@{%?how()who()why()select():
# True mul(973,686) ~why()where()![-(
# True mul(787,692) <!(,#{(/
# True mul(629,517) ~+
# True mul(10,499) +why()-(>?
# True mul(704,145) %
# True mul(811,825)  >
# True mul(539,875) ;*{
# True mul(920,111)
# True mul(509,272)
# True mul(657,901)
# True mul(464,17) >
# True mul(736,189) why()what()!why()*])}!
# True mul(299,45)
# True mul(532,593) when()select(169,279)><>[,
# True mul(627,971) {
# True mul(770,718) how()who()how()where(291,392)/[): do()!
# True mul(938,624) $&;!what()]?#^%
# True mul(279,222) what():<#how()@!~
# True mul(98,818) from()^++);:?why()$
# True mul(891,49) $(]#{%-
# True mul(526,69) +who(251,742)> what()where()<(
# True mul(119,943) }%when()]/(~#do()select()**+^-from()
# True mul(577,966) what()?from()when()*}<what()<]
# False mul(370,463) select(){select()*['>( don't()
# False mul(326,383) !why()>who()
# True mul(671,969) !~how(59,628)!; %do()
# True mul(747,375) !
# True mul(257,559)
# True mul(529,781) !?#!/<how(315,722)(
# True mul(118,474) <'[%?$
# True mul(866,674)
# True mul(99,500) %
# True mul(555,282) ?[who()do()who(394,637)^(+ [#(?{
# False mul(353,892) {-[*@!'select()where()don't()*{what();why()&>*
# False mul(648,3) select()why()(
# False mul(771,164) how()don't()<~{
# False mul(576,453)
# False mul(967,581) $why()}-@'

# %%
total
# Out:
# 62098619
